# %% [markdown]
# ## Molecule odor prediction via GINs with self-supervised contrastive pretraining

# %%
# toggle whether or not to use pretraining
use_pretraining = False

# %%
import torch
print("PyTorch has version {}".format(torch.__version__))
import torch_geometric
torch_geometric.__version__
import numpy as np

from torch_geometric.loader import DataLoader

import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
from tqdm import tqdm


import sys
sys.path.append('olf/GNNose/')
sys.path.append("GraphSSL/")


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

seed = 12345

torch_geometric.seed.seed_everything(seed)
# Out:
# PyTorch has version 1.13.1+cu117
# /home/nomam/.local/lib/python3.10/site-packages/torch_geometric/typing.py:70: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/nomam/.local/lib/python3.10/site-packages/torch_scatter/_scatter_cpu.so: undefined symbol: _ZNK3c107SymBool10guard_boolEPKcl
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/nomam/.local/lib/python3.10/site-packages/torch_geometric/typing.py:108: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/nomam/.local/lib/python3.10/site-packages/torch_sparse/_diag_cpu.so: undefined symbol: _ZN3c106detail19maybe_wrap_dim_slowIlEET_S2_S2_b
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
# initialize model and finetune
from odor_model import ScentClassifier
from odor_train import train, test
from torch_ema import ExponentialMovingAverage

def run_finetuning(model, device, num_epochs, lr, weight_decay):
    """Train or finetune the given model using the train/val sets"""

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ema = ExponentialMovingAverage(model.parameters(), decay=0.995)

    # track metrics
    roc_scores, f1_scores, accs, losses, val_losses, precision_scores, recall_scores = [], [], [], [], [], [], []

    for epoch in tqdm(range(num_epochs)):
        loss = train(model, optimizer, train_loader, 'train', device, weighted_BCE=True, ema=ema)
        val_loss = train(model, optimizer, val_loader, 'val', device, weighted_BCE=True)
        train_acc, train_preds, train_true  = test(model, train_loader, device)
        test_acc, test_preds, test_true = test(model, val_loader, device)

        # calculate bootstrapped ROC AUC score over entire val set
        _, whole_val_preds, whole_val_true = test(
            model, DataLoader(val_set, batch_size=len(val_set), shuffle=True), device)
        whole_val_preds = whole_val_preds.squeeze()
        whole_val_true = whole_val_true.squeeze()
        rocauc_score = 0
        # roc_auc_score(whole_val_true.cpu(), whole_val_preds.cpu())
        f1 = f1_score(whole_val_true.cpu(), whole_val_preds.cpu())
        precision = precision_score(whole_val_true.cpu(), whole_val_preds.cpu())
        recall = recall_score(whole_val_true.cpu(), whole_val_preds.cpu())


        # track metrics
        roc_scores.append(rocauc_score)
        f1_scores.append(f1)
        accs.append(test_acc)
        losses.append(loss)
        val_losses.append(val_loss)
        precision_scores.append(precision)
        recall_scores.append(recall)


    best_f1_score = max(f1_scores)
    best_f1_epoch = f1_scores.index(best_f1_score)
    best_auc_score = max(roc_scores)
    best_auc_epoch = roc_scores.index(best_auc_score)
    best_precison_score = max(precision_scores)
    best_recall_score = max(recall_scores)

    # plot_losses(losses, val_losses, title='finetuning: train vs. val loss')
    # fig, ax = plt.subplots(1, 2, figsize=(6, 2))
    # for i, (name, metric) in enumerate([
    #     ('f1', f1_scores), ('roc', roc_scores)
    # ]):
    #     ax[i].plot(range(len(metric)), metric)
    #     ax[i].set_ylim((0, 1))
    #     ax[i].set_title(name)
    # plt.show()

    return best_f1_score, best_f1_epoch, best_auc_score, best_auc_epoch, best_precison_score, best_recall_score

# %%
# from odor_data import get_graph_data
# graph_list = get_graph_data('ol','alcoholic') # 'ol' for Dream Olfaction dataset
# graph_list

# %%
# train_set, val_set, test_set = torch.utils.data.random_split(graph_list, [0.9, 0.05, 0.05])
# print(type(train_set))

# %%
# load and split the dataset
# 'alcoholic',
#  'aldehydic',
#  'alliaceous',
#  'almond',
#  'ambergris',
#  'ambery',

 # 'animalic',
 # 'anisic',
 # 'apple',
 # 'balsamic',
 # 'banana',
 # 'berry',
 # 'blackcurrant',
 # 'blueberry',
 # 'body',
 # 'bread',
 # 'burnt',
 # 'butter',
 # 'cacao',
 # 'camphor',
 # 'caramellic',
 # 'cedar',
 # 'cheese',
 # 'chemical',
 # 'cherry',
 # 'cinnamon',
 # 'citrus',
 # 'clean',
 # 'clove',
 # 'coconut',

 # 'cucumber',
 # 'dairy',
 # 'dry',
 # 'earthy',
 # 'ester',
 # 'ethereal',
 # 'fatty',
 # 'fermented',
 # 'floral',
 # 'fresh',
 # 'fruity',
 # 'geranium',
# 'grape',
#  'grapefruit',
#  'grass',
#  'green',
#  'herbal',
#  'honey',

# 'jasmin',
#  'lactonic',
#  'leaf',
#  'leather',
#  'lemon',
#  'lily',
#  'liquor',
#  'meat',
#  'medicinal',
#  'melon',
#  'metallic',
#  'mint',
#  'mushroom',
#  'musk',
#  'musty',
#  'nut',
#  'odorless',
#  'oily',
#  'orange',
# 'pear',
#  'pepper',
#  'phenolic',
#  'plastic',
#  'plum',
#  'powdery',
#  'pungent',
#  'rancid',
#  'resinous',
#  'ripe',
#  'roasted',
#  'rose',
#  'seafood',
 # 'sulfuric',
 # 'sweet',
 # 'syrup',
# 'tobacco',
#  'tropicalfruit',
#  'vanilla',
#  'vegetable',
#  'violetflower',
# 'watery',
#  'waxy',
#  'whiteflower',
#  'wine',
#  'woody'


 # 'coffee',
 # 'cognac',
 # 'coniferous',
 # 'cooked',
 # 'cooling',

 # 'fennel',

 # 'gourmand',
 
 # 'hyacinth',
 
 # 'overripe',
 
 # 'sharp',
 # 'smoky',
 # 'sour',
 # 'spicy',

 # 'terpenic',
 # 'ambrette',
# 
results = []
odor_list = [

 'ammoniac',

 
 
]

# odor_list = ["pungent","rose"]
from odor_data import get_graph_data

for odor in odor_list:
    print(odor)
    graph_list = get_graph_data('ol',odor) # 'ol' for Dream Olfaction dataset
    
    
    
    
    train_set, val_set, test_set = torch.utils.data.random_split(graph_list, [0.7, 0.05, 0.25])
    print(train_set)
    batch_size = 128
    
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader =  DataLoader(val_set, batch_size=batch_size, shuffle=True, drop_last=True)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True, drop_last=True)
    
    print(train_set)
    hidden_channels = 128
    num_layers = 2
    dropout_p = 0.25
    pooling_type = 'max'
    
    
    # set hyperparameters
    in_channels = list(graph_list[2].x.shape)[-1]
    print(in_channels)
    out_channels = 1
    
    
    
    
    if use_pretraining:
        from odor_pretrain import build_pretraining_loader, pretrain
        from odor_model import PretrainingGIN
    
        pretrain_epochs = 50
        pretrain_batch_size = 256
        pretrain_lr = 1e-3
        pretrain_weight_decay = 1e-4
    
        # We apply this approach using the GraphSSL GitHub repository.
        pretrain_train_loader = build_pretraining_loader(train_set, "train", batch_size=pretrain_batch_size)
        pretrain_val_loader = build_pretraining_loader(val_set, "val", batch_size=pretrain_batch_size)
    
    
    
    # apply pretraining
    if use_pretraining:
        pretrain_model = PretrainingGIN(
            in_channels,
            hidden_channels,
            num_layers,
            out_channels,
            dropout=dropout_p
        ).to(device)
    
        pretrain_optimizer = torch.optim.Adam(pretrain_model.parameters(), lr=pretrain_lr, weight_decay=pretrain_weight_decay)
    
        val_losses = []
        train_losses = []
        for epoch in (range(pretrain_epochs)):
            train_loss = pretrain(pretrain_model, pretrain_optimizer, epoch, "train", pretrain_train_loader, device)
            val_loss = pretrain(pretrain_model, pretrain_optimizer, epoch, "val", pretrain_val_loader, device)
            log = "Epoch {}, Train Loss: {:.3f}, Val Loss: {:.3f}"
            print(log.format(epoch, train_loss, val_loss))
    
            train_losses.append(train_loss)
            val_losses.append(val_loss)
    
        # plot_losses(train_losses, val_losses, "pretraining loss")
    
    num_epochs = 50
    lr = 1e-4
    weight_decay = 1e-3
    
    
    num_trials = 1
    dropout_p = 0.1
    trial_results = []
    
    for t in range(num_trials):
        model = ScentClassifier(
            in_channels,
            hidden_channels,
            num_layers,
            out_channels,
            dropout=dropout_p,
            pooling_type=pooling_type,
        )
        model = model.to(device)
    
        if use_pretraining:
            model.gnn.load_state_dict(
                pretrain_model.gnn.state_dict()
            )
    
        best_f1_score, best_f1_epoch, best_auc_score, best_auc_epoch, best_precision_score, best_recall_score = run_finetuning(model, device, num_epochs, lr, weight_decay)
        trial_results.append((best_f1_score, best_f1_epoch, best_auc_score, best_auc_epoch, best_precision_score, best_recall_score))
    
    
    hyperparam_tuning = True
    
    if hyperparam_tuning:
        import itertools
    
        param_search = {
            "lr": [1e-2, 5e-3, 1e-3],
            "weight_decay": [1e-5, 1e-6],
        }
    
        param_search_results = []
    
        for lr, weight_decay in list(itertools.product(*list(param_search.values()))):
            # create model
            model = ScentClassifier(
                in_channels,
                hidden_channels,
                num_layers,
                out_channels,
                dropout=dropout_p,
                pooling_type=pooling_type,
            )
            model = model.to(device)
    
            # load pretrained weights, if relevant
            if use_pretraining:
                model.gnn.load_state_dict(
                    pretrain_model.gnn.state_dict()
                )
    
            # train
            best_f1_score, best_f1_epoch, best_auc_score, best_auc_epoch, best_precision_score, best_recall_score = run_finetuning(
                model, device, num_epochs, lr, weight_decay)
    
            param_search_results.append(
                ((best_f1_score, best_f1_epoch, best_auc_score, best_auc_epoch, best_precision_score, best_recall_score), (lr, weight_decay))
            )
    if hyperparam_tuning:
        # show best results, by F1 or AUC
        param_search_results.sort(key = lambda x: x[0][0])
        print("Best F1 score:", param_search_results[-1][0][0])
        # print("Best F1 epoch:", param_search_results[-1][0][1])
        print(
            "Best F1 params:",
            dict(zip(
                param_search.keys(),
                param_search_results[-1][-1]
            ))
        )
    
        param_search_results.sort(key = lambda x: x[0][2])
        print("Best AUC score:", param_search_results[-1][0][2])
        # print("Best AUC epoch:", param_search_results[-1][0][3])
        print(
            "Best AUC params:",
            dict(zip(
                param_search.keys(),
                param_search_results[-1][-1]
            ))
        )

        param_search_results.sort(key = lambda x: x[0][4])
        print("Best Precision score:", param_search_results[-1][0][4])
        # print("Best AUC epoch:", param_search_results[-1][0][3])
        print(
            "Best Precision params:",
            dict(zip(
                param_search.keys(),
                param_search_results[-1][-1]
            ))
        )

        param_search_results.sort(key = lambda x: x[0][5])
        print("Best Recall score:", param_search_results[-1][0][5])
        # print("Best AUC epoch:", param_search_results[-1][0][3])
        print(
            "Best Recall params:",
            dict(zip(
                param_search.keys(),
                param_search_results[-1][-1]
            ))
        )

        results.append((odor,param_search_results[-1][0][0],param_search_results[-1][0][2],param_search_results[-1][0][4],param_search_results[-1][0][5]))
        # torch.save(model.state_dict(), '/Users/dishant/Desktop/base_model_3_12_2023_{0}.pth'.format(odor))
# Out:
# ammoniac
# <torch.utils.data.dataset.Subset object at 0x7f4c70112440>
# <torch.utils.data.dataset.Subset object at 0x7f4c70112440>
# 12
#   0%|                                                                                                                                                                                        | 0/50 [00:00<?, ?it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   2%|███▌                                                                                                                                                                            | 1/50 [00:00<00:42,  1.14it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   4%|███████                                                                                                                                                                         | 2/50 [00:01<00:37,  1.27it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#   6%|██████████▌                                                                                                                                                                     | 3/50 [00:02<00:33,  1.40it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   8%|██████████████                                                                                                                                                                  | 4/50 [00:02<00:32,  1.42it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  10%|█████████████████▌                                                                                                                                                              | 5/50 [00:03<00:32,  1.40it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  12%|█████████████████████                                                                                                                                                           | 6/50 [00:04<00:31,  1.42it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  14%|████████████████████████▋                                                                                                                                                       | 7/50 [00:05<00:31,  1.36it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  16%|████████████████████████████▏                                                                                                                                                   | 8/50 [00:05<00:28,  1.47it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  18%|███████████████████████████████▋                                                                                                                                                | 9/50 [00:06<00:27,  1.51it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  20%|███████████████████████████████████                                                                                                                                            | 10/50 [00:06<00:23,  1.72it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  22%|██████████████████████████████████████▌                                                                                                                                        | 11/50 [00:07<00:20,  1.90it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  24%|██████████████████████████████████████████                                                                                                                                     | 12/50 [00:07<00:18,  2.06it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  26%|█████████████████████████████████████████████▌                                                                                                                                 | 13/50 [00:07<00:16,  2.19it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  28%|█████████████████████████████████████████████████                                                                                                                              | 14/50 [00:08<00:15,  2.28it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  30%|████████████████████████████████████████████████████▌                                                                                                                          | 15/50 [00:08<00:14,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  32%|████████████████████████████████████████████████████████                                                                                                                       | 16/50 [00:09<00:14,  2.42it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  34%|███████████████████████████████████████████████████████████▌                                                                                                                   | 17/50 [00:09<00:14,  2.33it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  36%|███████████████████████████████████████████████████████████████                                                                                                                | 18/50 [00:10<00:14,  2.16it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  38%|██████████████████████████████████████████████████████████████████▌                                                                                                            | 19/50 [00:10<00:14,  2.18it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  40%|██████████████████████████████████████████████████████████████████████                                                                                                         | 20/50 [00:10<00:13,  2.17it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  42%|█████████████████████████████████████████████████████████████████████████▌                                                                                                     | 21/50 [00:11<00:12,  2.28it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  44%|█████████████████████████████████████████████████████████████████████████████                                                                                                  | 22/50 [00:11<00:11,  2.42it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  46%|████████████████████████████████████████████████████████████████████████████████▌                                                                                              | 23/50 [00:12<00:10,  2.51it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  48%|████████████████████████████████████████████████████████████████████████████████████                                                                                           | 24/50 [00:12<00:11,  2.24it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  50%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                       | 25/50 [00:13<00:12,  1.93it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                    | 26/50 [00:14<00:14,  1.71it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  54%|██████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                | 27/50 [00:14<00:14,  1.63it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████                                                                             | 28/50 [00:15<00:13,  1.61it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  58%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                         | 29/50 [00:16<00:13,  1.60it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                      | 30/50 [00:16<00:11,  1.72it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  62%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                  | 31/50 [00:17<00:10,  1.76it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                               | 32/50 [00:17<00:09,  1.86it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                           | 33/50 [00:17<00:08,  1.95it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                        | 34/50 [00:18<00:07,  2.03it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  70%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                    | 35/50 [00:18<00:07,  2.09it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 36/50 [00:19<00:06,  2.15it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  74%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                             | 37/50 [00:19<00:05,  2.21it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                          | 38/50 [00:20<00:06,  1.99it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                      | 39/50 [00:20<00:05,  2.03it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                   | 40/50 [00:21<00:04,  2.12it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  82%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                               | 41/50 [00:21<00:04,  2.15it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 42/50 [00:22<00:03,  2.22it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                        | 43/50 [00:22<00:03,  2.27it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                     | 44/50 [00:22<00:02,  2.29it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                 | 45/50 [00:23<00:02,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████              | 46/50 [00:23<00:01,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌          | 47/50 [00:24<00:01,  2.32it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████       | 48/50 [00:24<00:00,  2.35it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌   | 49/50 [00:25<00:00,  2.36it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:25<00:00,  1.96it/s]
#   0%|                                                                                                                                                                                        | 0/50 [00:00<?, ?it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   2%|███▌                                                                                                                                                                            | 1/50 [00:00<00:23,  2.12it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   4%|███████                                                                                                                                                                         | 2/50 [00:00<00:21,  2.20it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   6%|██████████▌                                                                                                                                                                     | 3/50 [00:01<00:20,  2.30it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   8%|██████████████                                                                                                                                                                  | 4/50 [00:01<00:20,  2.29it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  10%|█████████████████▌                                                                                                                                                              | 5/50 [00:02<00:19,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  12%|█████████████████████                                                                                                                                                           | 6/50 [00:02<00:19,  2.29it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  14%|████████████████████████▋                                                                                                                                                       | 7/50 [00:03<00:18,  2.28it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  16%|████████████████████████████▏                                                                                                                                                   | 8/50 [00:03<00:18,  2.32it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  18%|███████████████████████████████▋                                                                                                                                                | 9/50 [00:03<00:17,  2.28it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  20%|███████████████████████████████████                                                                                                                                            | 10/50 [00:04<00:17,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  22%|██████████████████████████████████████▌                                                                                                                                        | 11/50 [00:04<00:16,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  24%|██████████████████████████████████████████                                                                                                                                     | 12/50 [00:05<00:16,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  26%|█████████████████████████████████████████████▌                                                                                                                                 | 13/50 [00:05<00:16,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  28%|█████████████████████████████████████████████████                                                                                                                              | 14/50 [00:06<00:15,  2.31it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  30%|████████████████████████████████████████████████████▌                                                                                                                          | 15/50 [00:06<00:15,  2.33it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  32%|████████████████████████████████████████████████████████                                                                                                                       | 16/50 [00:06<00:14,  2.34it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  34%|███████████████████████████████████████████████████████████▌                                                                                                                   | 17/50 [00:07<00:13,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  36%|███████████████████████████████████████████████████████████████                                                                                                                | 18/50 [00:07<00:13,  2.39it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  38%|██████████████████████████████████████████████████████████████████▌                                                                                                            | 19/50 [00:08<00:13,  2.38it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  40%|██████████████████████████████████████████████████████████████████████                                                                                                         | 20/50 [00:08<00:12,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  42%|█████████████████████████████████████████████████████████████████████████▌                                                                                                     | 21/50 [00:09<00:12,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  44%|█████████████████████████████████████████████████████████████████████████████                                                                                                  | 22/50 [00:09<00:11,  2.39it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  46%|████████████████████████████████████████████████████████████████████████████████▌                                                                                              | 23/50 [00:09<00:11,  2.40it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  48%|████████████████████████████████████████████████████████████████████████████████████                                                                                           | 24/50 [00:10<00:11,  2.36it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  50%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                       | 25/50 [00:10<00:10,  2.35it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                    | 26/50 [00:11<00:10,  2.38it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  54%|██████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                | 27/50 [00:11<00:09,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████                                                                             | 28/50 [00:11<00:09,  2.35it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  58%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                         | 29/50 [00:12<00:08,  2.36it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                      | 30/50 [00:12<00:08,  2.36it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  62%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                  | 31/50 [00:13<00:07,  2.39it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                               | 32/50 [00:13<00:07,  2.40it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                           | 33/50 [00:14<00:07,  2.39it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                        | 34/50 [00:14<00:06,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  70%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                    | 35/50 [00:14<00:06,  2.37it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# /home/nomam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 36/50 [00:15<00:05,  2.39it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# ...
#   warnings.warn(message)
#  30%|████████████████████████████████████████████████████▌                                                                                                                          | 15/50 [00:07<00:17,  2.03it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  32%|████████████████████████████████████████████████████████                                                                                                                       | 16/50 [00:08<00:17,  1.89it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  34%|███████████████████████████████████████████████████████████▌                                                                                                                   | 17/50 [00:08<00:16,  1.97it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  36%|███████████████████████████████████████████████████████████████                                                                                                                | 18/50 [00:09<00:16,  1.99it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  38%|██████████████████████████████████████████████████████████████████▌                                                                                                            | 19/50 [00:09<00:15,  2.06it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  40%|██████████████████████████████████████████████████████████████████████                                                                                                         | 20/50 [00:10<00:14,  2.11it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  42%|█████████████████████████████████████████████████████████████████████████▌                                                                                                     | 21/50 [00:10<00:13,  2.15it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  44%|█████████████████████████████████████████████████████████████████████████████                                                                                                  | 22/50 [00:11<00:13,  2.01it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  46%|████████████████████████████████████████████████████████████████████████████████▌                                                                                              | 23/50 [00:11<00:13,  2.00it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  48%|████████████████████████████████████████████████████████████████████████████████████                                                                                           | 24/50 [00:12<00:12,  2.07it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  50%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                       | 25/50 [00:12<00:12,  1.97it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                    | 26/50 [00:13<00:11,  2.03it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  54%|██████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                | 27/50 [00:13<00:12,  1.80it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████                                                                             | 28/50 [00:14<00:12,  1.81it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  58%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                         | 29/50 [00:15<00:12,  1.72it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                      | 30/50 [00:15<00:10,  1.83it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  62%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                  | 31/50 [00:15<00:09,  1.91it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                               | 32/50 [00:16<00:09,  1.99it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                           | 33/50 [00:16<00:08,  2.07it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                        | 34/50 [00:17<00:07,  2.13it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  70%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                    | 35/50 [00:17<00:07,  1.97it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 36/50 [00:18<00:06,  2.05it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  74%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                             | 37/50 [00:18<00:06,  2.12it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                          | 38/50 [00:19<00:05,  2.13it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                      | 39/50 [00:19<00:05,  2.16it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                   | 40/50 [00:20<00:04,  2.10it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  82%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                               | 41/50 [00:20<00:04,  2.10it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 42/50 [00:21<00:03,  2.15it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                        | 43/50 [00:21<00:03,  2.12it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                     | 44/50 [00:22<00:02,  2.13it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                 | 45/50 [00:22<00:02,  2.13it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████              | 46/50 [00:23<00:02,  1.86it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌          | 47/50 [00:23<00:01,  1.87it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████       | 48/50 [00:24<00:01,  1.98it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌   | 49/50 [00:24<00:00,  2.06it/s]/home/nomam/.local/lib/python3.10/site-packages/torch_geometric/warnings.py:18: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:25<00:00,  2.00it/s]
# Best F1 score: 0.8
# Best F1 params: {'lr': 0.001, 'weight_decay': 1e-05}
# Best AUC score: 0
# Best AUC params: {'lr': 0.001, 'weight_decay': 1e-05}
# Best Precision score: 0.6666666666666666
# Best Precision params: {'lr': 0.001, 'weight_decay': 1e-05}
# Best Recall score: 1.0
# Best Recall params: {'lr': 0.001, 'weight_decay': 1e-05}
